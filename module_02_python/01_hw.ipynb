# %%
value = 3
value
# Out:
# 3

# %%
name = 'Alex'
age = 21
is_student = True

# %%
# 22.11.2025
print(name, age, is_student)
# Out:
# Alex 21 True

# %%
total_money = 100
price = 20

jar_count = total_money // price
jar_count
# Out:
# 5

# %%
a, b, c = 4, 25, 6

d = b ** 2 - 4 * a * c

d_sqrt = d ** 0.5

x_1 = (-b + d_sqrt) / 2 * a
x_2 = (-b - d_sqrt) / 2 * a
x_1, x_2
# Out:
# (-4.0, -96.0)

# %%
tasks_my = ['go to the market', 'make hw', 'walk with my dog']
tasks_friends = ['go to the movie', 'buy tickets', 'make hw']

# %%
tasks_all = tasks_my + tasks_friends
tasks_all
# Out:
# ['go to the market',
#  'make hw',
#  'walk with my dog',
#  'go to the movie',
#  'buy tickets',
#  'make hw']

# %%
tasks = {
    1: ['go to the market', 'walk with my dog'],
    2: ['make hw', 'make holiday gift for girlfriend'],
    3: [],
    4: [],
    5: []
}

# %%
if len(tasks[1]) > 0:
    print('Have important things')
else:
    print('You may have rest')
# Out:
# Have important things

# %%
values = []
for key in tasks:
    values.append(tasks.get(key))
    
values
# Out:
# [['go to the market', 'walk with my dog'],
#  ['make hw', 'make holiday gift for girlfriend'],
#  [],
#  [],
#  []]

# %%
doings = []
for key in tasks:
    doings.extend(tasks.get(key))
    
doings
# Out:
# ['go to the market',
#  'walk with my dog',
#  'make hw',
#  'make holiday gift for girlfriend']

# %%
answer = []
for key in tasks:
    for task in tasks.get(key):
        if 'go' in task:
            answer.append(task)
            
answer
# Out:
# ['go to the market']

# %%
answer = []
for key in tasks:
    for task in tasks.get(key):
        if key < 2:
            continue
        if len(answer) == 2:
            break
        if 'go' in task:
            answer.append(task)
            
answer
# Out:
# []

# %%
tasks = { 
    0: ["Покормить кота","Покормить кота"],
    1: ["Покормить кота", "Забрать посылку"]
}

new_tasks = {}

for key in tasks:
    new_tasks[key] = list(set(tasks.get(key)))
    
print(new_tasks)
# Out:
# {0: ['Покормить кота'], 1: ['Покормить кота', 'Забрать посылку']}
