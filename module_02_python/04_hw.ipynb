# %% [markdown]
# # Haeder 1
# ## Header 2
# ### etc
#
# This is markdown. I can write text and notes.
#
# Like this:
# - First step
# - Second step
# - Third step
#
# Also:
# 1. Hello
# 2. Python
# 3. Pandas
#
# And code
# ```python
# for i in range(10):
#     print(i)
# ```
#
# And more...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Working with pyplot

# %%
plt.plot([1, 2, 2], [4, 5, 6])

# %%
plt.scatter([1, 2, 3,], [1, 1, 1])

# %%
import numpy as np

# %%
# %time for _ in range(10*100): ...
# Out:
# CPU times: user 66 μs, sys: 7 μs, total: 73 μs
# Wall time: 79.2 μs

# %%
first = np.array([i for i in range(int(1e5))])
second = np.array([i for i in range(int(1e5))])

# %time np.dot(first, second)
# Out:
# CPU times: user 1.07 ms, sys: 115 μs, total: 1.19 ms
# Wall time: 1.42 ms
# np.int64(333328333350000)
